# %% [markdown]
# <a href="https://colab.research.google.com/github/Arundhathisree/FMML-IIIT-HYD/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 12:24:20--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  79.2MB/s    in 0.9s
#
# 2024-03-31 12:24:21 (79.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 16994  1707.08081v2  Search systems are often focused on providing ...    cs
# 36792   1411.6794v1  Two interpretations about syllogistic statemen...    cs
# 24577   1407.7317v1  The reduction of the cost of infrared (IR) cam...    cs
# 33289   0905.3771v1  The paper examines the problem of accessing a ...    cs
# 36784   1411.2186v1  Wildfires are frequent, devastating events in ...    cs
# ...             ...                                                ...   ...
# 16422  1702.04333v1  Previous studies support the idea of merging a...    cs
# 14476  cs/0102022v2  Home page of the workshop proceedings, with po...    cs
# 5396    1107.3600v2  In many scientific disciplines structures in h...  stat
# 29115  1708.04664v1  We are in the era of data analytics and data s...    cs
# 37886   1102.2075v1  We study the scenario of graph-based clusterin...  stat
#
#                                                    title  year  \
# 16994                Learning Word Relatedness over Time  2017
# 36792  Some Reflections on the Set-based and the Cond...  2014
# 24577   A unified framework for thermal face recognition  2014
# 33289               Memory Retrieved from Single Neurons  2009
# 36784  Estimating Fire Weather Indices via Semantic R...  2014
# ...                                                  ...   ...
# 16422  On the Relevance of Auditory-Based Gabor Featu...  2017
# 14476  Finite-State Phonology: Proceedings of the 5th...  2001
# 5396          Unsupervised K-Nearest Neighbor Regression  2011
# 29115  A Novel data Pre-processing method for multi-d...  2017
# 37886  How the result of graph clustering methods dep...  2011
#
#                                                 keywords
# 16994  [providing, significant, longitudinal, collect...
# 36792  [interpretations, syllogistic, statements, des...
# 24577  [reduction, recognition, particularly, attract...
# 33289  [accessing, different, neighboring, spreading,...
# 36784  [wildfires, devastating, australia, regularly,...
# ...                                                  ...
# 16422  [architectures, automatic, recognition, combin...
# 14476  [proceedings, individually, proceedings, phono...
# 5396   [scientific, disciplines, structures, dimensio...
# 29115  [analytics, abundance, biometrics, satellite, ...
# 37886  [clustering, algorithms, clustering, construct...
#
# [4800 rows x 6 columns]

# %%
df['keywords']

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8846 words.
# Out of those 4619 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5ba82d1b-792e-4aa8-b7b6-316137e3ee9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ba82d1b-792e-4aa8-b7b6-316137e3ee9c")) {                    Plotly.newPlot(                        "5ba82d1b-792e-4aa8-b7b6-316137e3ee9c",                        [{"x":["collections","newspapers","relatedness","temporally","introduce","significant","providing","achieving","retrieving","framework","challenge","identifying","digitized","understanding","extracted","application","historical","relationship","relationships","expansion","algorithmic","longitudinal","attending","quantified","development","interpretations","different","reasoning","described","antecedent","syllogisms","reflections","syllogistic","propositions","interpretation","questions","consequent","statements","proportional","conditional","recognition","variability","particularly","physiological","attractive","outstanding","invariance","concurrent","occlusion","extrinsic","reduction","advantage","illumination","appearance","conventional","expression","limitation","performance","identified","spreading","accessing","associated","suggested","retrieved","neighboring","fragments","continuous","variables","calculate","resources","measuring","thresholds","agreement","australia","resolution","describes","developed","localized","technologies","underlying","resolutions","challenges","ontologies","management","temperature","techniques","interface","wildfires","anticipating","widespread","calculating","precision","particular","estimating","standardized","outperforms","processing","evaluation","regularly","contribution","identification","robustness","characterize","approximate","nonnegative","competing","synthetic","successive","situations","generalize","solutions","hyperspectral","enclosing","equivalent","enhancing","precisions","optimization","competitively","semidefinite","interpreted","ellipsoid","additional","constraints","preconditioning","separable","relaxation","projection","factorization","algorithms","algorithm","objective","efficient","consuming","extremely","whitening","multiplicative","consistency","parametric","technical","condition","alternative","estimators","splitting","normality","expository","estimation","primarily","generalized","estimator","asymptotic","estimates","empirical","minimization","orthogonal","published","extractive","selection","presenting","representations","comprehension","decreases","answering","recurrent","candidates","prediction","extraction","architecture","predictions","typically","significantly","approaches","efficiently","arbitrary","formulations","similarities","demonstrate","contextual","confidence","personalized","applications","placement","corresponding","information","similarity","advantages","effective","recommendation","predictive","interpret","establish","satisfaction","investigated","experiments","acoustical","facilitate","strategies","important","presentation","assessment","thoroughly"],"y":[17,2,5,20,323,224,87,83,10,541,144,78,6,148,116,242,20,90,70,17,44,5,3,14,124,14,737,139,71,3,2,4,2,11,62,77,9,13,12,83,380,24,80,8,23,7,24,7,29,8,113,103,31,84,105,53,29,858,50,6,5,117,31,8,10,14,97,97,28,70,28,9,23,4,124,85,185,17,25,113,12,104,31,46,7,366,43,2,4,20,19,74,272,72,6,256,296,260,5,63,103,93,54,95,9,21,121,14,50,65,146,14,3,53,18,0,323,4,6,15,1,123,146,1,13,24,44,37,607,829,162,389,33,56,5,10,53,37,33,69,102,13,13,1,0,197,18,67,24,15,65,135,67,28,35,7,161,29,245,15,18,63,142,24,215,139,257,71,104,272,411,156,65,15,31,535,52,48,18,395,6,126,658,154,74,276,35,32,28,55,21,47,580,2,43,85,375,11,45,13],"type":"bar"},{"x":["collections","newspapers","relatedness","temporally","introduce","significant","providing","achieving","retrieving", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4619,), (4619, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5026455026455027);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Network</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315791);'>Regularization</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315791);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5026455026455027);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(RNNs)</span> <span style=''>with</span> <span style=''>Long</span> <span style=''>Short</span> <span style=''>Term</span> <span style=''>Memory</span> <span style=''>(LSTM)</span> <span style=''>units</span> <span style=''>Dropout</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizing</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>does</span> <span style=''>not</span> <span style=''>work</span> <span style=''>well</span> <span style=''>with</span> <span style=''>RNNs</span> <span style=''>and</span> <span style=''>LSTMs</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correctly</span> <span style=''>apply</span> <span style=''>dropout</span> <span style=''>to</span> <span style=''>LSTMs</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substantially</span> <span style=''>reduces</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>on</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>tasks</span> <span style=''>These</span> <span style=''>tasks</span> <span style=''>include</span> <span style=''>language</span> <span style=''>modeling</span> <span style=''>speech</span> <span style='background-color:rgba(0, 255, 0, 0.6344086021505377);'>recognition</span> <span style=''>image</span> <span style=''>caption</span> <span style='background-color:rgba(0, 255, 0, 0.5647058823529412);'>generation</span> <span style=''>and</span> <span style=''>machine</span> <span style='background-color:rgba(0, 255, 0, 0.8417266187050358);'>translation</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Consistent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>for</span> <span style=''>cluster</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>pruning</span> <br/><br/><span style=''>For</span> <span style=''>a</span> <span style=''>density</span> <span style=''>f</span> <span style=''>on</span> <span style=''>mathbb</span> <span style=''>Rd</span> <span style=''>a</span> <span style=''>it</span> <span style=''>high</span> <span style=''>density</span> <span style=''>cluster</span> <span style=''>is</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>of</span> <span style=''>x</span> <span style=''>f(x)</span> <span style=''>geq</span> <span style=''>lambda</span> <span style=''>for</span> <span style=''>some</span> <span style=''>lambda</span> <span style=''>0</span> <span style=''>The</span> <span style=''>set</span> <span style=''>of</span> <span style=''>all</span> <span style=''>high</span> <span style=''>density</span> <span style=''>clusters</span> <span style=''>forms</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchy</span> <span style=''>called</span> <span style=''>the</span> <span style=''>it</span> <span style=''>cluster</span> <span style=''>tree</span> <span style=''>of</span> <span style=''>f</span> <span style=''>We</span> <span style=''>present</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>cluster</span> <span style=''>tree</span> <span style=''>given</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>f</span> <span style=''>The</span> <span style=''>first</span> <span style=''>is</span> <span style=''>a</span> <span style=''>robust</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>single</span> <span style=''>linkage</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>The</span> <span style=''>second</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>k</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>graph</span> <span style=''>of</span> <span style=''>the</span> <span style=''>samples</span> <span style=''>We</span> <span style=''>give</span> <span style=''>finite</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rates</span> <span style=''>for</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>which</span> <span style=''>also</span> <span style=''>imply</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>and</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>cluster</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>study</span> <span style=''>a</span> <span style=''>tree</span> <span style=''>prunin ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>SafePredict</span> <span style=''>A</span> <span style=''>Meta</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>That</span> <span style=''>Uses</span> <span style=''>Refusals</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Guarantee</span> <span style='background-color:rgba(0, 255, 0, 0.4838709677419354);'>Correctness</span> <br/><br/><span style=''>SafePredict</span> <span style=''>is</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>meta</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>works</span> <span style=''>with</span> <span style=''>any</span> <span style=''>base</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>online</span> <span style=''>data</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrarily</span> <span style=''>chosen</span> <span style='background-color:rgba(0, 255, 0, 0.4838709677419354);'>correctness</span> <span style=''>rate</span> <span style=''>1</span> <span style=''>epsilon</span> <span style=''>by</span> <span style=''>allowing</span> <span style=''>refusals</span> <span style=''>Allowing</span> <span style=''>refusals</span> <span style=''>means</span> <span style=''>that</span> <span style=''>the</span> <span style=''>meta</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>may</span> <span style=''>refuse</span> <span style=''>to</span> <span style=''>emit</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>the</span> <span style=''>base</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style=''>occasion</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style=''>error</span> <span style=''>rate</span> <span style=''>on</span> <span style=''>non</span> <span style=''>refused</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>does</span> <span style=''>not</span> <span style=''>exceed</span> <span style=''>epsilon</span> <span style=''>The</span> <span style=''>SafePredict</span> <span style=''>error</span> <span style=''>bound</span> <span style=''>does</span> <span style=''>not</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.4020618556701031);'>assumptions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>or</span> <span style=''>the</span> <span style=''>base</span> <span style='background-color:rgba(255, 0, 0, 0.47826086956521735);'>predictor</span> <span style=''>When</span> <span style=''>the</span> <span style=''>base</span> <span style='background-color:rgba(255, 0, 0, 0.47826086956521735);'>predictor</span> <span style=''>happens</span> <span style=''>not</span> <span style=''>to</span> <span style=''>exceed</span> <span style=''>the</span> <span style=''>target</span> <span style=''>error</span> <span style=''>rate</span> <span style=''>epsilon</span> <span style=''>SafePredict</span> <span style=''>refuses</span> <span style=''>only</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>number</span> <span style=''>of</span> <span style=''>times</span> <span style=''>When</span> <span style=''>the</span> <span style=''>error ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Language</span> <span style=''>depedent</span> <span style=''>I</span> <span style=''>Vectors</span> <span style=''>for</span> <span style=''>LRE15</span> <br/><br/><span style=''>A</span> <span style=''>standard</span> <span style=''>recipe</span> <span style=''>for</span> <span style=''>spoken</span> <span style=''>language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>is</span> <span style=''>to</span> <span style=''>apply</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>back</span> <span style=''>end</span> <span style=''>to</span> <span style=''>i</span> <span style=''>vectors</span> <span style=''>This</span> <span style=''>ignores</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style=''>the</span> <span style=''>i</span> <span style=''>vector</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style=''>which</span> <span style=''>could</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>for</span> <span style=''>short</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utterances</span> <span style=''>A</span> <span style=''>recent</span> <span style=''>paper</span> <span style=''>by</span> <span style=''>Cumani</span> <span style=''>Plchot</span> <span style=''>and</span> <span style=''>Fer</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>solution</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagate</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>into</span> <span style=''>the</span> <span style=''>backend</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07069271758436944)
# 	segmentation (0.06678507992895204)
# 	experimental (0.13925399644760214)
# 	information (0.23374777975133215)
# 	architecture (0.09129662522202486)
# 	knowledge (0.12646536412078152)
# 	different (0.2618117229129662)
# 	detection (0.11829484902309059)
# 	convolutional (0.13392539964476022)
# 	recognition (0.1349911190053286)
#
# Some Statistics words are:
# 	convergence (0.12241813602015113)
# 	estimation (0.16473551637279596)
# 	stochastic (0.14307304785894207)
# 	algorithm (0.39395465994962214)
# 	statistical (0.15113350125944586)
# 	distribution (0.18488664987405543)
# 	variables (0.14055415617128464)
# 	dimensional (0.18085642317380352)
# 	inference (0.18841309823677582)
# 	regression (0.1858942065491184)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8f9f27d7-5908-45b8-9560-105824e4b62d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f9f27d7-5908-45b8-9560-105824e4b62d")) {                    Plotly.newPlot(                        "8f9f27d7-5908-45b8-9560-105824e4b62d",                        [{"x":["collections","newspapers","relatedness","temporally","introduce","significant","providing","achieving","retrieving","framework","challenge","identifying","digitized","understanding","extracted","application","historical","relationship","relationships","expansion","algorithmic","longitudinal","attending","quantified","development","interpretations","different","reasoning","described","antecedent","syllogisms","reflections","syllogistic","propositions","interpretation","questions","consequent","statements","proportional","conditional","recognition","variability","particularly","physiological","attractive","outstanding","invariance","concurrent","occlusion","extrinsic","reduction","advantage","illumination","appearance","conventional","expression","limitation","performance","identified","spreading","accessing","associated","suggested","retrieved","neighboring","fragments","continuous","variables","calculate","resources","measuring","thresholds","agreement","australia","resolution","describes","developed","localized","technologies","underlying","resolutions","challenges","ontologies","management","temperature","techniques","interface","wildfires","anticipating","widespread","calculating","precision","particular","estimating","standardized","outperforms","processing","evaluation","regularly","contribution","identification","robustness","characterize","approximate","nonnegative","competing","synthetic","successive","situations","generalize","solutions","hyperspectral","enclosing","equivalent","enhancing","precisions","optimization","competitively","semidefinite","interpreted","ellipsoid","additional","constraints","preconditioning","separable","relaxation","projection","factorization","algorithms","algorithm","objective","efficient","consuming","extremely","whitening","multiplicative","consistency","parametric","technical","condition","alternative","estimators","splitting","normality","expository","estimation","primarily","generalized","estimator","asymptotic","estimates","empirical","minimization","orthogonal","published","extractive","selection","presenting","representations","comprehension","decreases","answering","recurrent","candidates","prediction","extraction","architecture","predictions","typically","significantly","approaches","efficiently","arbitrary","formulations","similarities","demonstrate","contextual","confidence","personalized","applications","placement","corresponding","information","similarity","advantages","effective","recommendation","predictive","interpret","establish","satisfaction","investigated","experiments","acoustical","facilitate","strategies","important","presentation","assessment","thoroughly","environment","classifiers","conclusions","conducted","reverberation","recommendations","affecting","classrooms","education","subjective","continuously","classroom","probability","attribute","presented","exchanged","attributes","assumption","calculated","independence","describing","distribution","concerning","constraint","exponential","polynomial","furthermore","appropriate","probabilities","independent","successfully","prototypical","parameterized","structure","consisting","available","classification","supervised","producing","challenging","unlabeled","augmented","hierarchical","benchmarks","extensions","classifier","situation","representing","prototypes","interested","instruction","manipulation","generates","experimental","generated","construct","cond ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	precisions
# 	expository
# 	favourable
# 	pedagogical
# 	parametrically
# 	determinants
# 	literally
# 	posteriors
# 	tempering
# 	exchangeability
# 	interpolates
# 	leaderboard
# 	positivity
# 	uncollapsed
# 	nonparanormal
# 	unbiasedness
# 	exponents
# 	cumulants
# 	timestamps
# 	criminology
# Some words which never appear in Statistics papers:
# 	newspapers
# 	digitized
# 	attending
# 	syllogisms
# 	reflections
# 	syllogistic
# 	consequent
# 	illumination
# 	australia
# 	wildfires
# 	anticipating
# 	extractive
# 	acoustical
# 	reverberation
# 	affecting
# 	classrooms
# 	classroom
# 	instruction
# 	sourcetarget
# 	multiobjective

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0516646830846227e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
